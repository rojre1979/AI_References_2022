# %% [markdown]
# <a href="https://colab.research.google.com/github/rojre1979/AI_References_2022/blob/main/BasicDataScienceDay2pt3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4)

# %%
points = data[0]

# %%
# create scatter plot
plt.figure(figsize = (20, 10))
# plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='viridis')
plt.scatter(data[0][:,0], data[0][:,1])
plt.xlim(-15,15)
plt.ylim(-15,15)
# Out:
# (-15.0, 15.0)

# %%
# import KMeans
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=7)

# %%
model.fit(points)
# Out:
# KMeans(n_clusters=7)

# %%
y_pred = model.fit_predict(points)

# %%
y_pred
# Out:
# array([5, 2, 2, 5, 1, 3, 2, 3, 2, 3, 3, 2, 0, 1, 1, 6, 0, 2, 3, 3, 1, 1,
#        3, 3, 2, 3, 3, 0, 3, 3, 1, 4, 4, 4, 2, 2, 5, 0, 3, 1, 0, 4, 5, 0,
#        0, 3, 6, 2, 4, 6, 3, 6, 3, 3, 4, 0, 3, 3, 6, 0, 2, 0, 5, 5, 4, 4,
#        5, 2, 4, 4, 2, 5, 0, 3, 3, 0, 3, 2, 4, 2, 2, 4, 3, 5, 4, 2, 3, 4,
#        4, 6, 6, 1, 0, 2, 3, 2, 2, 2, 2, 1, 4, 4, 1, 0, 3, 2, 3, 2, 4, 6,
#        3, 5, 3, 1, 6, 6, 6, 5, 0, 1, 3, 5, 2, 4, 5, 1, 3, 4, 2, 3, 4, 3,
#        3, 4, 1, 2, 0, 4, 5, 1, 3, 3, 3, 3, 4, 1, 3, 2, 0, 0, 5, 1, 3, 0,
#        4, 5, 3, 5, 1, 4, 5, 0, 0, 1, 1, 2, 1, 2, 5, 3, 3, 3, 6, 1, 4, 6,
#        1, 3, 1, 5, 6, 5, 3, 0, 2, 2, 3, 5, 6, 3, 1, 2, 2, 5, 5, 5, 3, 3,
#        4, 2], dtype=int32)

# %%
plt.figure(figsize = (20, 10))
plt.scatter(points[y_pred ==0,0], points[y_pred == 0,1], s=100, c='red')
plt.scatter(points[y_pred ==1,0], points[y_pred == 1,1], s=100, c='black')
plt.scatter(points[y_pred ==2,0], points[y_pred == 2,1], s=100, c='blue')
plt.scatter(points[y_pred ==3,0], points[y_pred == 3,1], s=100, c='yellow')
plt.scatter(points[y_pred ==4,0], points[y_pred == 4,1], s=100, c='green')
plt.scatter(points[y_pred ==5,0], points[y_pred == 5,1], s=100, c='cyan')
plt.scatter(points[y_pred ==6,0], points[y_pred == 6,1], s=100, c='orange')
